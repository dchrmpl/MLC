# %% [markdown]
# ## Домашнє завдання 2.2. Тема 2. Основи синтаксису Python¶
# Виконавець: Черемісін
#
# ### 1.Списки - базові операції

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]
print (temperatures)
# Out:
# [22, 25, 19, 23, 26, 20, 21, 22]

# %%
print(temperatures [0])
print(temperatures [7])
temperatures.append(24)
print(temperatures [8])
# Out:
# 22
# 22
# 24

# %%
temperatures.remove(19)
print (temperatures)
# Out:
# [22, 25, 23, 26, 20, 21, 22, 24]

# %%
print(len(temperatures))
# Out:
# 8

# %%
print(sum(temperatures))
# Out:
# 183

# %%
print(max(temperatures))
# Out:
# 26

# %% [markdown]
# ### 2.Словники - базові операції

# %%
dch = {
    "name": "Denys",
    "age": 38,
    "city": "Marki",
    }
print(dch)
# Out:
# {'name': 'Denys', 'age': 38, 'city': 'Marki'}

# %%
print(dch["name"])
# Out:
# Denys

# %%
dch["age"] = 21
print(dch["age"])
# Out:
# 21

# %%
print(dch.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
print(dch.values())
# Out:
# dict_values(['Denys', 21, 'Marki'])
