# %% [markdown]
# ## Домашнє завдання. Тема 2. Основи синтаксису Python
# Виконавець: Черемісін

# %% [markdown]
# ### 1. Створення змінних

# %%
name = "Denys"
age = 38
height = 1.85
is_student = False

# %%
print (name, age, height, is_student, sep='\n')
# Out:
# Denys
# 38
# 1.85
# False

# %% [markdown]
# ### 2. Арифметичні операції

# %%
var1 = 15
var2 = 4
print (var1, var2, sep='\n')
# Out:
# 15
# 4

# %%
sum_ = var1 + var2 
dif = var1 - var2 
mult = var1 * var2 
div = var1 / var2 
int_div = var1 // var2 
rem_div = var1 % var2 
rai_pow = var1 ** var2 

print (sum_, dif, mult, div, int_div, rem_div, rai_pow, sep='\n')
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %% [markdown]
# ### 3. Робота з рядками

# %%
last_name = 'Cheremisin'
last_name
# Out:
# 'Cheremisin'

# %%
print (last_name)
# Out:
# Cheremisin

# %%
full_name = name + " " + last_name
print (full_name)
print (full_name.upper())
print (full_name.lower())
print (len((full_name)))     # Чиста довжина рядка
print (len((full_name)) - 1) # Кількість літер, виключив пробіл
print (fr"Мене звати {full_name}, мені {age} років.")
# Out:
# Denys Cheremisin
# DENYS CHEREMISIN
# denys cheremisin
# 16
# 15
# Мене звати Denys Cheremisin, мені 38 років.
